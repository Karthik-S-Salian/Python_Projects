# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv("../resources/Excel_sheets/canada_per_capita_income.csv")
df.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
df.columns=["year","per_capita_income"]

# %%
df.head()
# Out:
#    year  per_capita_income
# 0  1970        3399.299037
# 1  1971        3768.297935
# 2  1972        4251.175484
# 3  1973        4804.463248
# 4  1974        5576.514583

# %%
matplotlib.rcParams['figure.figsize']=(15,10)
plt.plot(df.year,df.per_capita_income,marker='*',color='#630ff0')
plt.xlabel('year')
plt.ylabel('per_capita_income')
plt.show()

# %%
X=df.year.values.reshape(-1, 1)
y=df.per_capita_income

# %%
reg=LinearRegression()
model=reg.fit(X,y)

# %%
model.predict([[2020]])
# Out:
# array([41288.69409442])

# %%
model.intercept_
# Out:
# -1632210.7578554575

# %%
model.coef_
# Out:
# array([828.46507522])

# %%
a=model.coef_
b=model.intercept_

# %%
y_points=np.array([x*a+b for x in df.year])

# %%
plt.plot(df.year,df.per_capita_income,marker='*',color='red')
plt.plot(df.year,y_points,"bo--",markersize=5,alpha=0.5) #"bo--"color,marker,marker_of_gap [here o=circle]
plt.xlabel('year')
plt.ylabel('per_capita_income')
plt.show()

# %% [markdown]
# SAVING TRAINED MODEL TO FILE USING PICKLE

# %%
import pickle

# %%
with open('../resources/model/model_pickle','wb') as f:
    pickle.dump(model,f)

# %%
with open('../resources/model/model_pickle','rb') as f:
    saved_model=pickle.load(f)

# %%
saved_model.predict([[2000]])
