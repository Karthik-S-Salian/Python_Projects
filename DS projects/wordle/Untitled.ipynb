# %%
import re
with open("C:/Users/Dell/Downloads/words.txt") as f:
    words=re.findall(r'[A-Za-z]+',f.read())

# %%
len(words)
# Out:
# 2669

# %%
with open("C:/Users/Dell/Downloads/words_alpha.txt") as f:
    list_5_letters=[]
    for word in f.readlines():
        word=re.findall(r'[A-Za-z]+',word)[0]
        if len(word)==5:
            list_5_letters.append(word)

# %%
final_count=dict()
for i in range(5):
    count=dict()
    for word in list_5_letters:
        count[word[i]]=count.get(word[i],0)+1
    final_count[str(i)]=count
final_count
# Out:
# {'0': {'a': 1174,
#   'b': 1141,
#   'c': 1196,
#   'd': 801,
#   'e': 421,
#   'f': 684,
#   'g': 737,
#   'h': 571,
#   'y': 167,
#   'i': 301,
#   'j': 260,
#   'k': 473,
#   'l': 679,
#   'm': 849,
#   'n': 406,
#   'o': 334,
#   'p': 944,
#   'q': 85,
#   'r': 681,
#   's': 1813,
#   't': 981,
#   'u': 328,
#   'v': 287,
#   'w': 468,
#   'x': 27,
#   'z': 112},
#  '1': {'a': 2871,
#   'b': 109,
#   'c': 254,
#   'd': 136,
#   'e': 1971,
#   'f': 40,
#   'g': 102,
#   'h': 720,
#   'y': 279,
#   'i': 1669,
#   'j': 19,
#   'k': 101,
#   'l': 866,
#   'm': 233,
#   'n': 557,
#   'o': 2281,
#   'p': 283,
#   'q': 21,
#   'r': 1151,
#   's': 173,
#   't': 316,
#   'u': 1403,
#   'v': 81,
#   'w': 174,
#   'x': 74,
#   'z': 36},
#  '2': {'h': 208,
#   'l': 1061,
#   'r': 1545,
#   'a': 1481,
#   'b': 446,
#   'd': 514,
#   'e': 1027,
#   'i': 1267,
#   'y': 229,
#   'k': 309,
#   'm': 649,
#   'n': 1238,
#   'o': 1154,
#   's': 682,
#   'u': 787,
#   'w': 276,
#   'c': 531,
# ...

# %%
count=dict()
for word in list_5_letters:
    count[word[0]]=count.get(word[0],0)+1
count
# Out:
# {'a': 1174,
#  'b': 1141,
#  'c': 1196,
#  'd': 801,
#  'e': 421,
#  'f': 684,
#  'g': 737,
#  'h': 571,
#  'y': 167,
#  'i': 301,
#  'j': 260,
#  'k': 473,
#  'l': 679,
#  'm': 849,
#  'n': 406,
#  'o': 334,
#  'p': 944,
#  'q': 85,
#  'r': 681,
#  's': 1813,
#  't': 981,
#  'u': 328,
#  'v': 287,
#  'w': 468,
#  'x': 27,
#  'z': 112}

# %%
sum=0
for key,values in count_1.items():
    sum+=values
    
print(sum//26)
# Out:
# 69

# %%
count_1=dict()
for word in list_5_letters:
    if word[0]=='s':
        count_1[word[1]]=count_1.get(word[1],0)+1
count_1
# Out:
# {'a': 214,
#  'c': 126,
#  'd': 1,
#  'e': 150,
#  'f': 2,
#  'h': 182,
#  'i': 130,
#  'y': 20,
#  'j': 1,
#  'k': 73,
#  'l': 107,
#  'm': 43,
#  'n': 70,
#  'o': 137,
#  'p': 153,
#  'q': 12,
#  'r': 1,
#  's': 3,
#  't': 215,
#  'u': 99,
#  'v': 1,
#  'w': 73}

# %%
for i in range
# Out:
# 5.298317366548036

# %%
final_count=dict()
for i in range(5):
    count=dict()
    for word in list_5_letters:
        count[word[i]]=count.get(word[i],0)+1
    final_count[str(i)]=count
final_count
# Out:
# {'0': {'a': 1174,
#   'b': 1141,
#   'c': 1196,
#   'd': 801,
#   'e': 421,
#   'f': 684,
#   'g': 737,
#   'h': 571,
#   'y': 167,
#   'i': 301,
#   'j': 260,
#   'k': 473,
#   'l': 679,
#   'm': 849,
#   'n': 406,
#   'o': 334,
#   'p': 944,
#   'q': 85,
#   'r': 681,
#   's': 1813,
#   't': 981,
#   'u': 328,
#   'v': 287,
#   'w': 468,
#   'x': 27,
#   'z': 112},
#  '1': {'a': 2871,
#   'b': 109,
#   'c': 254,
#   'd': 136,
#   'e': 1971,
#   'f': 40,
#   'g': 102,
#   'h': 720,
#   'y': 279,
#   'i': 1669,
#   'j': 19,
#   'k': 101,
#   'l': 866,
#   'm': 233,
#   'n': 557,
#   'o': 2281,
#   'p': 283,
#   'q': 21,
#   'r': 1151,
#   's': 173,
#   't': 316,
#   'u': 1403,
#   'v': 81,
#   'w': 174,
#   'x': 74,
#   'z': 36},
#  '2': {'h': 208,
#   'l': 1061,
#   'r': 1545,
#   'a': 1481,
#   'b': 446,
#   'd': 514,
#   'e': 1027,
#   'i': 1267,
#   'y': 229,
#   'k': 309,
#   'm': 649,
#   'n': 1238,
#   'o': 1154,
#   's': 682,
#   'u': 787,
#   'w': 276,
#   'c': 531,
# ...

# %%
max_letter=0
max_count=0
for i in range(5):
    for key,value in final_count[str(i)].items():
        if value>max_count:
            max_count=value
            max_letter=key
    print(f'pos = {i} , {max_count = } {max_letter = } \n')
    max_letter=0
    max_count=0
# Out:
# pos = 0 , max_count = 1813 max_letter = 's'
#
# pos = 1 , max_count = 2871 max_letter = 'a'
#
# pos = 2 , max_count = 1545 max_letter = 'r'
#
# pos = 3 , max_count = 2510 max_letter = 'e'
#
# pos = 4 , max_count = 3148 max_letter = 's'

# %%
s=0
for letter in 'sares':
    s += ord(letter)
s
# Out:
# 542

# %%
for word in list_5_letters:
    s=0
    for letter in word:
        s += ord(letter)
    if 520<s<550:
        print(word,s)
# Out:
# aaron 529
# aberr 524
# abets 527
# abhor 524
# abyes 532
# abysm 540
# abyss 546
# ablow 533
# abnet 522
# abody 527
# aboon 527
# abort 536
# abote 523
# about 539
# above 525
# abray 527
# abret 526
# abrim 523
# abrin 524
# abris 529
# abrus 541
# absey 532
# absis 530
# absit 531
# abstr 540
# abune 523
# abura 523
# abuse 528
# abush 531
# abuta 525
# abuts 543
# acapu 522
# acast 524
# accoy 527
# accts 526
# accum 521
# accur 526
# accus 527
# achoo 522
# achor 525
# acidy 522
# acyls 540
# ackey 525
# aclys 540
# acmes 521
# acnes 522
# acoin 522
# acool 526
# acorn 531
# acost 538
# acoup 536
# acres 526
# acryl 539
# acron 531
# acrux 547
# actin 527
# acton 533
# actor 537
# actos 538
# actus 544
# acute 530
# adays 530
# adapt 522
# adaty 531
# adawn 523
# adeps 525
# adept 526
# adfix 524
# adion 523
# adios 528
# adyta 531
# adits 533
# adlay 523
# adlet 522
# admin 521
# admit 527
# admix 531
# admov 535
# admrx 540
# adnex 528
# adopt 536
# adore 523
# adorn 532
# ...

# %%
for word in list_5_letters:
    if word[2]=='a':
        if 's' in word:
            if 'i' in word:
                if 'u' in word:
                    print(word)
# Out:
# quais
# quasi
# siafu
# udasi
# unais

# %%
for word in list_5_letters:
    if word[2]=='a':
        if word[1]=='r':
            if 't' in word:
                if not 'n' in word:
                    if not 'd' in word:
                        if not 'd' in word:
                            if not 's' in word:
                                print(word)
# Out:
# arati
# bract
# craft
# crate
# erato
# fract
# frate
# graft
# grata
# grate
# irate
# kraft
# krait
# kraut
# orate
# prate
# pratt
# trabu
# trace
# tracy
# track
# tract
# tragi
# traik
# trail
# trait
# trama
# trame
# tramp
# trapa
# trapt
# trave
# trawl
# urate
# wrapt
# wrath

# %%
for word in list_5_letters:
    if not 'a' in word:
        if not 'r' in word:
            if 'e' in word:
                if  'n' in word:
                    if  'i' in word:
                        if  'l' in word:
                            if not 't' in word:
                                if not 's' in word:
                                    print(word)
# Out:
# bison
# cions
# coins
# cosin
# dinos
# donis
# eosin
# foins
# icons
# ikons
# infos
# inkos
# insol
# yonis
# isoln
# joins
# kinos
# kosin
# linos
# lions
# loins
# ninos
# nobis
# noils
# noise
# noisy
# nosig
# oinks
# oisin
# opsin
# oscin
# pions
# scion
# sinon
# soign
# sonic
# sozin
# vinos
# vison
# winos

# %%
not_present=['b','n','l']
present=[('e',3)]
pos_list=[('r',1),('a',0),('i',2)]
out=[]
for word in list_5_letters:
    for letter,pos in pos_list:
        if not word[pos]==letter:
            break
    else:
        for letter,pos in present:
            if word[pos]==letter:
                break
            if not letter in word:
                break
        else:
            for letter in not_present:
                if letter in word:
                    break
            else:
                out.append(word)
set(out)
# Out:
# {'arise', 'arite'}

# %%
with open("answer_word",'r') as f:
# Out:
# {'garth', 'gator', 'gotra', 'graft', 'grant', 'grata', 'groat'}
