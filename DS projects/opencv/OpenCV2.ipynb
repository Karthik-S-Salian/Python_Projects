# %%
import cv2
from matplotlib.pyplot import imshow
# %matplotlib inline
from IPython.display import Image

# %%
icv=cv2.imread("resources\Images\minecraft.jpg",cv2.IMREAD_UNCHANGED)

# %%
Image(filename="resources\Images\minecraft.jpg")

# %%
imshow(i)

# %%
from PIL import Image as Img

# %%
i
# Out:
# array([[[255, 126,  64],
#         [255, 126,  64],
#         [255, 124,  62],
#         ...,
#         [255, 212, 195],
#         [255, 212, 195],
#         [255, 212, 195]],
#
#        [[250, 118,  54],
#         [252, 118,  54],
#         [251, 115,  51],
#         ...,
#         [255, 212, 195],
#         [255, 212, 195],
#         [255, 212, 195]],
#
#        [[254, 123,  56],
#         [253, 122,  55],
#         [253, 119,  55],
#         ...,
#         [255, 212, 195],
#         [255, 212, 195],
#         [255, 212, 195]],
#
#        ...,
#
#        [[ 60, 174, 137],
#         [ 54, 175, 137],
#         [ 46, 178, 138],
#         ...,
#         [251, 189,  19],
#         [251, 189,  19],
#         [251, 189,  19]],
#
#        [[ 51, 176, 137],
#         [ 44, 177, 137],
#         [ 38, 179, 138],
#         ...,
#         [251, 189,  19],
#         [251, 189,  19],
#         [251, 189,  19]],
#
#        [[ 40, 178, 137],
#         [ 35, 179, 137],
#         [ 29, 181, 138],
# ...

# %%
ipil=Img.fromarray(icv)
ipil
# Out:
# <PIL.Image.Image image mode=RGB size=500x244>

# %%
import numpy as np

# %%
np.array(ipil)
# Out:
# array([[[255, 126,  64],
#         [255, 126,  64],
#         [255, 124,  62],
#         ...,
#         [255, 212, 195],
#         [255, 212, 195],
#         [255, 212, 195]],
#
#        [[250, 118,  54],
#         [252, 118,  54],
#         [251, 115,  51],
#         ...,
#         [255, 212, 195],
#         [255, 212, 195],
#         [255, 212, 195]],
#
#        [[254, 123,  56],
#         [253, 122,  55],
#         [253, 119,  55],
#         ...,
#         [255, 212, 195],
#         [255, 212, 195],
#         [255, 212, 195]],
#
#        ...,
#
#        [[ 60, 174, 137],
#         [ 54, 175, 137],
#         [ 46, 178, 138],
#         ...,
#         [251, 189,  19],
#         [251, 189,  19],
#         [251, 189,  19]],
#
#        [[ 51, 176, 137],
#         [ 44, 177, 137],
#         [ 38, 179, 138],
#         ...,
#         [251, 189,  19],
#         [251, 189,  19],
#         [251, 189,  19]],
#
#        [[ 40, 178, 137],
#         [ 35, 179, 137],
#         [ 29, 181, 138],
# ...

# %%
type(ipil)
# Out:
# PIL.Image.Image

# %%
rgb_icv=cv2.cvtColor(icv,cv2.COLOR_BGR2RGB)
imshow(rgb_icv)
